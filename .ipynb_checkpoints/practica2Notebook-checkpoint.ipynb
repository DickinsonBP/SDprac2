# %%
#ejecutar main.py

# %%
# %run main.py
# Out:
# 2021-06-17 23:38:16,320 [INFO] lithops.config -- Lithops v2.3.4
# 2021-06-17 23:38:16,327 [INFO] lithops.storage.backends.ibm_cos.ibm_cos -- IBM COS Storage client created - Region: eu-de
# 2021-06-17 23:38:16,329 [INFO] lithops.serverless.backends.ibm_cf.ibm_cf -- IBM CF client created - Region: eu-gb - Namespace: anna.graciac@estudiants.urv.cat_dev
# 2021-06-17 23:38:16,330 [INFO] lithops.executors -- Serverless Executor created with ID: 7c9559-3
# 2021-06-17 23:38:16,331 [INFO] lithops.invokers -- ExecutorID 7c9559-3 | JobID A000 - Selected Runtime: lithopscloud/ibmcf-python-v39 - 256MB
# 2021-06-17 23:38:16,336 [INFO] lithops.job.job -- ExecutorID 7c9559-3 | JobID A000 - Uploading function and data - Total: 1.8KiB
# 2021-06-17 23:38:16,766 [INFO] lithops.invokers -- ExecutorID 7c9559-3 | JobID A000 - Starting function invocation: tratar_archivo() - Total: 1 activations
# 2021-06-17 23:38:16,768 [INFO] lithops.invokers -- ExecutorID 7c9559-3 | JobID A000 - View execution logs at /tmp/lithops/logs/7c9559-3-A000.log
# 2021-06-17 23:38:16,782 [INFO] lithops.storage.backends.ibm_cos.ibm_cos -- IBM COS Storage client created - Region: eu-de
# 2021-06-17 23:38:20,241 [INFO] lithops.invokers -- ExecutorID 7c9559-3 | JobID A001 - Selected Runtime: lithopscloud/ibmcf-python-v39 - 256MB
# 2021-06-17 23:38:20,247 [INFO] lithops.job.job -- ExecutorID 7c9559-3 | JobID A001 - Uploading function and data - Total: 1.8KiB
# 2021-06-17 23:38:20,440 [INFO] lithops.invokers -- ExecutorID 7c9559-3 | JobID A001 - Starting function invocation: tratar_archivo() - Total: 1 activations
# 2021-06-17 23:38:20,442 [INFO] lithops.invokers -- ExecutorID 7c9559-3 | JobID A001 - View execution logs at /tmp/lithops/logs/7c9559-3-A001.log
# 2021-06-17 23:38:20,460 [INFO] lithops.storage.backends.ibm_cos.ibm_cos -- IBM COS Storage client created - Region: eu-de

# %%
import geopandas as gpd 
import pandas as pd 
import matplotlib.pyplot as plt

datos = pd.read_csv('datos/Comarca.csv') 
datos = pd.DataFrame(datos, columns=['Comarca','Casos']) 
datos.head(42)
datos['Comarca'] = datos['Comarca'].astype(str)
#datos['Casos'] = datos['Casos'].astype(str)
#print(datos)
cat = gpd.read_file('datos/shapefiles_catalunya_comarcas.shp',enconding='utf-8')
#cambiar a mayusculas y quitar acentos
cat['nom_comar'] = cat['nom_comar'].str.upper()
a,b = 'ÀÈÍÓÚÜÑ','AEIOUUN'
trans = str.maketrans(a,b)
cat['nom_comar'] = cat['nom_comar'].str.translate(trans)

#hacer merge con el dataframe
cat = cat.merge(datos, left_on=['nom_comar'],right_on=['Comarca'], how='left')
plt.rcParams["figure.figsize"]=10,10

#mostrar mapa
cat.plot(
    column='Casos',
    legend=True,
    linewidth = 0.4,
    edgecolor='black',
    cmap = 'Blues')
# Out:
# <AxesSubplot:>
